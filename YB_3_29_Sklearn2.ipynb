# %% [markdown]
# <a href="https://colab.research.google.com/github/ggoddll99/ds_study/blob/main/YB_3_29_Sklearn2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 데이터 설명 : 비행탑승 경험 만족도
# #### x_train: https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_train.csv
# #### x_test: https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_test.csv
# 출처 (참고, 데이터 수정)

# %%
import pandas as pd
train = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_train.csv')
test = pd.read_csv('https://raw.githubusercontent.com/Datamanim/datarepo/main/airline/x_test.csv')

# %%
train.head()
# Out:
#    ID  Gender   Customer Type  Age   Type of Travel     Class  \
# 0   0  Female  Loyal Customer   54  Personal Travel       Eco
# 1   2    Male  Loyal Customer   20  Personal Travel       Eco
# 2   3    Male  Loyal Customer   59  Business travel  Business
# 3   4    Male  Loyal Customer   35  Business travel  Eco Plus
# 4   5  Female  Loyal Customer    9  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             1068                      3                                  4
# 1             1546                      4                                  4
# 2             2962                      0                                  4
# 3              106                      5                                  4
# 4             2917                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       3  ...                       5                 5
# 1                       4  ...                       4                 3
# 2                       0  ...                       1                 1
# 3                       4  ...                       5                 2
# 4                       3  ...                       4                 4
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 3                 5                3                 5
# 1                 3                 4                4                 4
# 2                 1                 1                5                 1
# 3                 1                 5                4                 4
# 4                 4                 5                4                 3
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  id
# 0            3                          47                      22.0 NaN
# 1            4                           5                       2.0 NaN
# 2            4                          54                      46.0 NaN
# 3            5                         130                     121.0 NaN
# 4            4                           0                       0.0 NaN
#
# [5 rows x 24 columns]

# %%
test.head()
# Out:
#    ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   1    Male     Loyal Customer   28  Business travel  Business
# 1  16  Female  disloyal Customer   34  Business travel       Eco
# 2  17  Female     Loyal Customer   23  Personal Travel       Eco
# 3  25    Male     Loyal Customer   55  Business travel  Business
# 4  27  Female     Loyal Customer   44  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             3414                      2                                  2
# 1             2556                      1                                  1
# 2              363                      2                                  5
# 3             2079                      1                                  1
# 4              192                      2                                  4
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# 0                       2  ...                       2                 4
# 1                       1  ...                       2                 5
# 2                       2  ...                       5                 3
# 3                       1  ...                       1                 1
# 4                       5  ...                       1                 1
#
#    Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                 5                 4                4                 4
# 1                 1                 5                1                 3
# 2                 2                 4                5                 4
# 3                 1                 1                4                 1
# 4                 2                 1                5                 1
#
#    Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes       id
# 0            2                           0                       0.0  40819.0
# 1            2                          15                       0.0  33335.0
# 2            5                           0                       0.0  20749.0
# 3            3                           0                       0.0  92194.0
# 4            1                          23                      13.0  13904.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ## 1. MinMaxScaler
#
# ### Question. train 데이터의 Age 컬럼을 MinMax 스케일링하여 얻은 값을 age_mm_scaling 컬럼에 추가한 후, train셋과 같은 기준으로 test 데이터의 Age를 스케일링하고 그 결과를 age_mm_scaling 컬럼에 추가하라.

# %% [markdown]
# ####step1. 'MinMaxScaler'를 사용하기 위한 라이브러리를 import하기

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# #### step2. MinMaxScaler 객체 생성

# %%
scaler=MinMaxScaler()

# %% [markdown]
# #### step3. train 데이터의 Age를 2차원 형태로 변환 후 이를 a1이라는 데이터로 저장

# %%
a1=train[['Age']]

# %% [markdown]
# #### step4. MinMaxScaler 객체를 사용하여 데이터를 학습

# %%
scaler.fit(a1)
# Out:
# MinMaxScaler()

# %% [markdown]
# #### step5. 학습된 MinMaxScaler 객체를 사용하여 'Age'열의 데이터를 변환하고, 'age_scaling'컬럼에 추가

# %%
arr = scaler.transform(a1)
df1 = pd.DataFrame(arr, columns=['age_scaling'])
train=pd.concat([train, df1], axis=1)

# %%
train
# Out:
#            ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0           0  Female     Loyal Customer   54  Personal Travel       Eco
# 1           2    Male     Loyal Customer   20  Personal Travel       Eco
# 2           3    Male     Loyal Customer   59  Business travel  Business
# 3           4    Male     Loyal Customer   35  Business travel  Eco Plus
# 4           5  Female     Loyal Customer    9  Business travel  Business
# ...       ...     ...                ...  ...              ...       ...
# 83118  103893  Female     Loyal Customer   52  Personal Travel  Eco Plus
# 83119  103898    Male     Loyal Customer   56  Personal Travel  Business
# 83120  103899  Female     Loyal Customer   26  Business travel  Business
# 83121  103901    Male  disloyal Customer   23  Business travel       Eco
# 83122  103903    Male     Loyal Customer   35  Personal Travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 0                 1068                      3
# 1                 1546                      4
# 2                 2962                      0
# 3                  106                      5
# 4                 2917                      3
# ...                ...                    ...
# 83118              748                      3
# 83119              601                      1
# 83120             1259                      5
# 83121              833                      5
# 83122              362                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                      4                       3  ...
# 1                                      4                       4  ...
# 2                                      4                       0  ...
# 3                                      4                       4  ...
# 4                                      3                       3  ...
# ...                                  ...                     ...  ...
# 83118                                  5                       3  ...
# 83119                                  4                       1  ...
# 83120                                  5                       5  ...
# 83121                                  5                       5  ...
# 83122                                  5                       3  ...
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                     5                 3                 5                3
# 1                     3                 3                 4                4
# 2                     1                 1                 1                5
# 3                     2                 1                 5                4
# 4                     4                 4                 5                4
# ...                 ...               ...               ...              ...
# 83118                 3                 3                 3                5
# 83119                 4                 1                 4                3
# 83120                 4                 2                 5                5
# 83121                 4                 3                 3                4
# 83122                 3                 3                 3                5
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                     5            3                          47
# 1                     4            4                           5
# 2                     1            4                          54
# 3                     4            5                         130
# 4                     3            4                           0
# ...                 ...          ...                         ...
# 83118                 3            3                         115
# 83119                 4            1                          13
# 83120                 5            5                           0
# 83121                 5            3                           0
# 83122                 3            5                          37
#
#        Arrival Delay in Minutes  id  age_scaling
# 0                          22.0 NaN     0.602564
# 1                           2.0 NaN     0.166667
# 2                          46.0 NaN     0.666667
# 3                         121.0 NaN     0.358974
# 4                           0.0 NaN     0.025641
# ...                         ...  ..          ...
# 83118                     124.0 NaN     0.576923
# 83119                      12.0 NaN     0.628205
# 83120                       0.0 NaN     0.243590
# 83121                       0.0 NaN     0.205128
# 83122                      36.0 NaN     0.358974
#
# [83123 rows x 25 columns]

# %% [markdown]
# #### step6. test 데이터에서도 'Age'컬럼을 추출하여 2차원 배열 형태로 변환하고, 학습된 MinMaxScaler 객체를 사용하여 test 데이터의 'Age'열을 변환 후 이를 'age_mm_scaling'컬럼에 추가

# %%
a2=test[['Age']]

# %%
arr = scaler.transform(a2)
df2 = pd.DataFrame(arr, columns=['age_mm_scaling'])
test=pd.concat([test, df2], axis=1)
test
# Out:
#            ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0           1    Male     Loyal Customer   28  Business travel  Business
# 1          16  Female  disloyal Customer   34  Business travel       Eco
# 2          17  Female     Loyal Customer   23  Personal Travel       Eco
# 3          25    Male     Loyal Customer   55  Business travel  Business
# 4          27  Female     Loyal Customer   44  Business travel       Eco
# ...       ...     ...                ...  ...              ...       ...
# 20776  103895    Male     Loyal Customer   58  Business travel       Eco
# 20777  103896  Female     Loyal Customer    9  Personal Travel       Eco
# 20778  103897  Female     Loyal Customer   46  Business travel  Business
# 20779  103900    Male     Loyal Customer   35  Business travel  Business
# 20780  103902  Female     Loyal Customer   48  Business travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 0                 3414                      2
# 1                 2556                      1
# 2                  363                      2
# 3                 2079                      1
# 4                  192                      2
# ...                ...                    ...
# 20776              802                      3
# 20777              436                      3
# 20778             3611                      2
# 20779             2762                      1
# 20780              829                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                      2                       2  ...
# 1                                      1                       1  ...
# 2                                      5                       2  ...
# 3                                      1                       1  ...
# 4                                      4                       5  ...
# ...                                  ...                     ...  ...
# 20776                                  2                       2  ...
# 20777                                  2                       3  ...
# 20778                                  2                       2  ...
# 20779                                  4                       4  ...
# 20780                                  2                       2  ...
#
#        On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                     4                 5                 4                4
# 1                     5                 1                 5                1
# 2                     3                 2                 4                5
# 3                     1                 1                 1                4
# 4                     1                 2                 1                5
# ...                 ...               ...               ...              ...
# 20776                 3                 3                 3                2
# 20777                 3                 1                 3                1
# 20778                 4                 4                 4                3
# 20779                 1                 2                 1                1
# 20780                 2                 2                 2                1
#
#        Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                     4            2                           0
# 1                     3            2                          15
# 2                     4            5                           0
# 3                     1            3                           0
# 4                     1            1                          23
# ...                 ...          ...                         ...
# 20776                 3            4                           0
# 20777                 3            1                           0
# 20778                 4            3                           0
# 20779                 1            1                           0
# 20780                 2            4                          74
#
#        Arrival Delay in Minutes        id  age_mm_scaling
# 0                           0.0   40819.0        0.269231
# 1                           0.0   33335.0        0.346154
# 2                           0.0   20749.0        0.205128
# 3                           0.0   92194.0        0.615385
# 4                          13.0   13904.0        0.474359
# ...                         ...       ...             ...
# 20776                       0.0  109641.0        0.653846
# 20777                       0.0   96541.0        0.025641
# 20778                       0.0   87270.0        0.500000
# 20779                       0.0   31889.0        0.358974
# 20780                      68.0   26505.0        0.525641
#
# [20781 rows x 25 columns]

# %% [markdown]
# ## 2. StandardScaler
#
# ### Question. train 데이터의 Age 컬럼을 sklearn 모듈을 활용하여 정규화 스케일링한 결과를 age_s_scaling 컬럼에 추가한 후, train셋과 같은 기준으로 test 데이터의 Age를 스케일링하여 age_s_scaling 컬럼에 추가하라.

# %% [markdown]
# #### step1. 'StandScaler'를 사용하기 위한 라이브러리를 import하기

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #### step2. StandardScaler 객체 생성

# %%
scaler=StandardScaler()

# %% [markdown]
# #### step3. train 데이터의 Age를 2차원 형태로 변환 후 이를 a1라는 데이터로 저장

# %%
a1=train[['Age']]

# %% [markdown]
# #### step4. StandScaler 객체를 사용하여 데이터를 학습

# %%
scaler.fit(a1)
# Out:
# StandardScaler()

# %% [markdown]
# #### step5. 학습된  StandardScaler 객체를 사용하여 'Age'열의 데이터를 변환하고, 'age_s_scaling'컬럼에 추가

# %%
arr=scaler.transform(a1)
df2 = pd.DataFrame(arr, columns=['age_s_scaling'])
train=pd.concat([train, df2], axis=1)
train
# Out:
#            ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0           0  Female     Loyal Customer   54  Personal Travel       Eco
# 1           2    Male     Loyal Customer   20  Personal Travel       Eco
# 2           3    Male     Loyal Customer   59  Business travel  Business
# 3           4    Male     Loyal Customer   35  Business travel  Eco Plus
# 4           5  Female     Loyal Customer    9  Business travel  Business
# ...       ...     ...                ...  ...              ...       ...
# 83118  103893  Female     Loyal Customer   52  Personal Travel  Eco Plus
# 83119  103898    Male     Loyal Customer   56  Personal Travel  Business
# 83120  103899  Female     Loyal Customer   26  Business travel  Business
# 83121  103901    Male  disloyal Customer   23  Business travel       Eco
# 83122  103903    Male     Loyal Customer   35  Personal Travel  Business
#
#        Flight Distance  Inflight wifi service  \
# 0                 1068                      3
# 1                 1546                      4
# 2                 2962                      0
# 3                  106                      5
# 4                 2917                      3
# ...                ...                    ...
# 83118              748                      3
# 83119              601                      1
# 83120             1259                      5
# 83121              833                      5
# 83122              362                      3
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                      4                       3  ...
# 1                                      4                       4  ...
# 2                                      4                       0  ...
# 3                                      4                       4  ...
# 4                                      3                       3  ...
# ...                                  ...                     ...  ...
# 83118                                  5                       3  ...
# 83119                                  4                       1  ...
# 83120                                  5                       5  ...
# 83121                                  5                       5  ...
# 83122                                  5                       3  ...
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                     3                 5                3                 5
# 1                     3                 4                4                 4
# 2                     1                 1                5                 1
# 3                     1                 5                4                 4
# 4                     4                 5                4                 3
# ...                 ...               ...              ...               ...
# 83118                 3                 3                5                 3
# 83119                 1                 4                3                 4
# 83120                 2                 5                5                 5
# 83121                 3                 3                4                 5
# 83122                 3                 3                5                 3
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  id  \
# 0                3                          47                      22.0 NaN
# 1                4                           5                       2.0 NaN
# 2                4                          54                      46.0 NaN
# 3                5                         130                     121.0 NaN
# 4                4                           0                       0.0 NaN
# ...            ...                         ...                       ...  ..
# 83118            3                         115                     124.0 NaN
# 83119            1                          13                      12.0 NaN
# 83120            5                           0                       0.0 NaN
# 83121            3                           0                       0.0 NaN
# 83122            5                          37                      36.0 NaN
#
#        age_scaling  age_s_scaling
# 0         0.602564       0.969366
# 1         0.166667      -1.281932
# 2         0.666667       1.300439
# 3         0.358974      -0.288712
# 4         0.025641      -2.010293
# ...            ...            ...
# 83118     0.576923       0.836936
# 83119     0.628205       1.101795
# 83120     0.243590      -0.884644
# 83121     0.205128      -1.083288
# 83122     0.358974      -0.288712
#
# [83123 rows x 26 columns]

# %% [markdown]
# #### step6. test 데이터에서도 'Age'컬럼을 추출하여 2차원 배열 형태로 변환하고, 학습된 StandardScaler 객체를 사용하여 test데이터의 'Age'열을 변환 후 'age_s_scaling'컬럼에 추가

# %%
a2=test[['Age']]
arr=scaler.transform(a2)
df3 = pd.DataFrame(arr, columns=['age_s_scaling'])
test=pd.concat([test, df3], axis=1)
test
# Out:
#            ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0           1    Male     Loyal Customer   28  Business travel  Business
# 1          16  Female  disloyal Customer   34  Business travel       Eco
# 2          17  Female     Loyal Customer   23  Personal Travel       Eco
# 3          25    Male     Loyal Customer   55  Business travel  Business
# 4          27  Female     Loyal Customer   44  Business travel       Eco
# ...       ...     ...                ...  ...              ...       ...
# 20776  103895    Male     Loyal Customer   58  Business travel       Eco
# 20777  103896  Female     Loyal Customer    9  Personal Travel       Eco
# 20778  103897  Female     Loyal Customer   46  Business travel  Business
# 20779  103900    Male     Loyal Customer   35  Business travel  Business
# 20780  103902  Female     Loyal Customer   48  Business travel       Eco
#
#        Flight Distance  Inflight wifi service  \
# 0                 3414                      2
# 1                 2556                      1
# 2                  363                      2
# 3                 2079                      1
# 4                  192                      2
# ...                ...                    ...
# 20776              802                      3
# 20777              436                      3
# 20778             3611                      2
# 20779             2762                      1
# 20780              829                      2
#
#        Departure/Arrival time convenient  Ease of Online booking  ...  \
# 0                                      2                       2  ...
# 1                                      1                       1  ...
# 2                                      5                       2  ...
# 3                                      1                       1  ...
# 4                                      4                       5  ...
# ...                                  ...                     ...  ...
# 20776                                  2                       2  ...
# 20777                                  2                       3  ...
# 20778                                  2                       2  ...
# 20779                                  4                       4  ...
# 20780                                  2                       2  ...
#
#        Leg room service  Baggage handling  Checkin service  Inflight service  \
# 0                     5                 4                4                 4
# 1                     1                 5                1                 3
# 2                     2                 4                5                 4
# 3                     1                 1                4                 1
# 4                     2                 1                5                 1
# ...                 ...               ...              ...               ...
# 20776                 3                 3                2                 3
# 20777                 1                 3                1                 3
# 20778                 4                 4                3                 4
# 20779                 2                 1                1                 1
# 20780                 2                 2                1                 2
#
#        Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                2                           0                       0.0
# 1                2                          15                       0.0
# 2                5                           0                       0.0
# 3                3                           0                       0.0
# 4                1                          23                      13.0
# ...            ...                         ...                       ...
# 20776            4                           0                       0.0
# 20777            1                           0                       0.0
# 20778            3                           0                       0.0
# 20779            1                           0                       0.0
# 20780            4                          74                      68.0
#
#              id  age_mm_scaling  age_s_scaling
# 0       40819.0        0.269231      -0.752215
# 1       33335.0        0.346154      -0.354927
# 2       20749.0        0.205128      -1.083288
# 3       92194.0        0.615385       1.035580
# 4       13904.0        0.474359       0.307219
# ...         ...             ...            ...
# 20776  109641.0        0.653846       1.234224
# 20777   96541.0        0.025641      -2.010293
# 20778   87270.0        0.500000       0.439649
# 20779   31889.0        0.358974      -0.288712
# 20780   26505.0        0.525641       0.572078
#
# [20781 rows x 26 columns]

# %% [markdown]
# #### train 데이터에 추가된 age_mm_scaling 칼럼과 age_s_scaling 칼럼 확인하기

# %%
train.head()
# Out:
#    ID  Gender   Customer Type  Age   Type of Travel     Class  \
# 0   0  Female  Loyal Customer   54  Personal Travel       Eco
# 1   2    Male  Loyal Customer   20  Personal Travel       Eco
# 2   3    Male  Loyal Customer   59  Business travel  Business
# 3   4    Male  Loyal Customer   35  Business travel  Eco Plus
# 4   5  Female  Loyal Customer    9  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             1068                      3                                  4
# 1             1546                      4                                  4
# 2             2962                      0                                  4
# 3              106                      5                                  4
# 4             2917                      3                                  3
#
#    Ease of Online booking  ...  Leg room service  Baggage handling  \
# 0                       3  ...                 3                 5
# 1                       4  ...                 3                 4
# 2                       0  ...                 1                 1
# 3                       4  ...                 1                 5
# 4                       3  ...                 4                 5
#
#    Checkin service  Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                3                 5            3                          47
# 1                4                 4            4                           5
# 2                5                 1            4                          54
# 3                4                 4            5                         130
# 4                4                 3            4                           0
#
#    Arrival Delay in Minutes  id  age_scaling  age_s_scaling
# 0                      22.0 NaN     0.602564       0.969366
# 1                       2.0 NaN     0.166667      -1.281932
# 2                      46.0 NaN     0.666667       1.300439
# 3                     121.0 NaN     0.358974      -0.288712
# 4                       0.0 NaN     0.025641      -2.010293
#
# [5 rows x 26 columns]

# %% [markdown]
# #### test 데이터에 추가된 age_mm_scaling 칼럼과 age_s_scaling 칼럼 확인하기

# %%
test.head()
# Out:
#    ID  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   1    Male     Loyal Customer   28  Business travel  Business
# 1  16  Female  disloyal Customer   34  Business travel       Eco
# 2  17  Female     Loyal Customer   23  Personal Travel       Eco
# 3  25    Male     Loyal Customer   55  Business travel  Business
# 4  27  Female     Loyal Customer   44  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0             3414                      2                                  2
# 1             2556                      1                                  1
# 2              363                      2                                  5
# 3             2079                      1                                  1
# 4              192                      2                                  4
#
#    Ease of Online booking  ...  Leg room service  Baggage handling  \
# 0                       2  ...                 5                 4
# 1                       1  ...                 1                 5
# 2                       2  ...                 2                 4
# 3                       1  ...                 1                 1
# 4                       5  ...                 2                 1
#
#    Checkin service  Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                4                 4            2                           0
# 1                1                 3            2                          15
# 2                5                 4            5                           0
# 3                4                 1            3                           0
# 4                5                 1            1                          23
#
#    Arrival Delay in Minutes       id  age_mm_scaling  age_s_scaling
# 0                       0.0  40819.0        0.269231      -0.752215
# 1                       0.0  33335.0        0.346154      -0.354927
# 2                       0.0  20749.0        0.205128      -1.083288
# 3                       0.0  92194.0        0.615385       1.035580
# 4                      13.0  13904.0        0.474359       0.307219
#
# [5 rows x 26 columns]
